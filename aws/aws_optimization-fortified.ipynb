# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import csv
import datetime as dt
import re
import time
import dateutil
data = '/home/joe/data/aws/out.csv'
df = pd.read_csv(data)
#df.head(10)

# %%
print(df.describe())
# Out:
#        i-0ca364ec6656ff517  i-089389afc8097dac4  i-09f0182499b5eaf27
# count          4464.000000          4464.000000          4464.000000
# mean              0.055788             0.717365             0.074835
# std               0.057696             0.221718             0.121549
# min               0.000007             0.009213             0.000020
# 25%               0.014152             0.588501             0.014324
# 50%               0.035984             0.765885             0.037939
# 75%               0.080933             0.897953             0.090088
# max               0.418851             0.999747             1.000000

# %%
datestrings = df['datetime'].to_list()
dates = [dateutil.parser.parse(s) for s in datestrings]

fig = plt.figure(figsize=(12,6))
ax=plt.gca()

ax.set_title("AWS EC2 Utilizations", fontsize=20)
ax.set_ylabel('CPU Utilization', color='black',fontsize=18)
ax.set_xlabel('Date', color='black',fontsize=18)

dateticks = [20200301,20200308,20200315,20200322,20200329]
dateticksX = [dt.datetime.strptime(str(int(dtx)),'%Y%m%d') for dtx in dateticks]

ax.set_xticks(dateticksX)
xfmt = mdates.DateFormatter('%m-%d')
ax.xaxis.set_major_formatter(xfmt)
plt.ylim(0,1)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.plot(dates,df['i-089389afc8097dac4'], color="blue")
plt.plot(dates,df['i-09f0182499b5eaf27'], color="red")
plt.plot(dates,df['i-0ca364ec6656ff517'], color="green")
plt.legend(['i-089389afc8097dac4','i-09f0182499b5eaf27','i-0ca364ec6656ff517'], fontsize=18)
plt.show()

# %%
datestrings = df['datetime'].to_list()
dates = [dateutil.parser.parse(s) for s in datestrings]

fig = plt.figure(figsize=(12,6))
ax=plt.gca()

ax.set_title("AWS EC2 Utilizations", fontsize=20)
ax.set_ylabel('CPU Utilization', color='black',fontsize=18)
ax.set_xlabel('Date', color='black',fontsize=18)

dateticks = [20200301,20200308,20200315,20200322,20200329]
dateticksX = [dt.datetime.strptime(str(int(dtx)),'%Y%m%d') for dtx in dateticks]

ax.set_xticks(dateticksX)
xfmt = mdates.DateFormatter('%m-%d')
ax.xaxis.set_major_formatter(xfmt)
plt.ylim(0,1)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
#plt.plot(dates,df['i-089389afc8097dac4'], color="blue")
#plt.plot(dates,df['i-09f0182499b5eaf27'], color="red")
plt.plot(dates,df['i-0ca364ec6656ff517'], color="green")
plt.legend(['i-089389afc8097dac4','i-09f0182499b5eaf27','i-0ca364ec6656ff517'], fontsize=18)
plt.show()
